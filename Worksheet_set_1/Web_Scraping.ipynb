# %% [markdown]
# # All header tags from wikipedia

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', titles, sep='\n\n')
# Out:
# List all the header tags :
#
# [<h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none">Main Page</h1>, <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>, <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>, <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>, <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>, <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>, <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>, <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>, <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>, <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>, <h2>Navigation menu</h2>, <h3 class="vector-menu-heading" id="p-personal-label">
# <span class="vector-menu-heading-label">Personal tools</span>
# </h3>, <h3 class="vector-menu-heading" id="p-namespaces-label">
# <span class="vector-menu-heading-label">Namespaces</span>
# </h3>, <h3 class="vector-menu-heading" id="p-views-label">
# <span class="vector-menu-heading-label">Views</span>
# </h3>, <h3>
# <label for="searchInput">Search</label>
# </h3>, <h3 class="vector-menu-heading" id="p-navigation-label">
# <span class="vector-menu-heading-label">Navigation</span>
# </h3>, <h3 class="vector-menu-heading" id="p-interaction-label">
# <span class="vector-menu-heading-label">Contribute</span>
# </h3>, <h3 class="vector-menu-heading" id="p-tb-label">
# <span class="vector-menu-heading-label">Tools</span>
# </h3>, <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span class="vector-menu-heading-label">Print/export</span>
# </h3>, <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span class="vector-menu-heading-label">In other projects</span>
# </h3>, <h3 class="vector-menu-heading" id="p-lang-label">
# <span class="vector-menu-heading-label">Languages</span>
# </h3>]

# %% [markdown]
# # Imdb Movies

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd


url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
movies = soup.select('td.titleColumn')
ratings = [b.attrs.get('data-value')
		for b in soup.select('td.posterColumn span[name=ir]')]

list = []


for index in range(0, len(movies)):
    
	movie_string = movies[index].get_text()
	movie = (' '.join(movie_string.split()).replace('.', ''))
	movie_title = movie[len(str(index))+1:-7]
	year = re.search('\((.*?)\)', movie_string).group(1)
	data = {
			"movie_title": movie_title,
			"rating": ratings[index],
			"year": year,
			}
	list.append(data)

for movie in list:
	print (movie['movie_title'], movie['year'], movie['rating'])
# Out:
# The Shawshank Redemption 1994 9.233893063206908
# The Godfather 1972 9.155979151228378
# The Dark Knight 2008 8.985601644497793
# The Godfather Part II 1974 8.984201393677512
# 12 Angry Men 1957 8.947739391584205
# Schindler's List 1993 8.935273524481374
# The Lord of the Rings: The Return of the King 2003 8.921216382909272
# Pulp Fiction 1994 8.850675209952154
# The Lord of the Rings: The Fellowship of the Ring 2001 8.803660620857306
#  Il buono, il brutto, il cattivo 1966 8.793589773185268
# Forrest Gump 1994 8.76731858687504
# Fight Club 1999 8.749880659765422
# Inception 2010 8.732919945809707
# The Lord of the Rings: The Two Towers 2002 8.727904540266966
# The Empire Strikes Back 1980 8.70166147827435
# The Matrix 1999 8.670961250969581
# Goodfellas 1990 8.651638353950833
# One Flew Over the Cuckoo's Nest 1975 8.641126100923286
# Se7en 1995 8.604044393477158
# Shichinin no samurai 1954 8.5989104157606
# It's a Wonderful Life 1946 8.596904878281505
# The Silence of the Lambs 1991 8.588010839455807
# Cidade de Deus 2002 8.57882879953153
# Saving Private Ryan 1998 8.577762234261076
# La vita è bella 1997 8.566063159557961
# The Green Mile 1999 8.55977086960093
# Interstellar 2014 8.555722514033468
# Star Wars 1977 8.554053831864733
# Terminator 2: Judgment Day 1991 8.535108999242166
# Back to the Future 1985 8.51815886731042
# Sen to Chihiro no kamikakushi 2001 8.51538722785252
# Psycho 1960 8.508691145089786
# The Pianist 2002 8.504530192974991
# Léon 1994 8.500496897660945
# Gisaengchung 2019 8.495681314280288
# The Lion King 1994 8.48843954183021
# Gladiator 2000 8.485381412208287
# American History X 1998 8.484415485009514
# The Usual Suspects 1995 8.47629376257264
# The Departed 2006 8.475113220192702
# The Prestige 2006 8.467996308106805
# Casablanca 1942 8.46565210537688
# Top Gun: Maverick 2022 8.461826922863207
# Whiplash 2014 8.460428777974643
# The Intouchables 2011 8.453702142569284
# Modern Times 1936 8.44963369647637
# Seppuku 1962 8.448607725670676
# Once Upon a Time in the West 1968 8.447649537255337
# Hotaru no haka 1988 8.447599489122728
# Rear Window 1954 8.43719292708094
# Alien 1979 8.435171130221745
# City Lights 1931 8.43406193286829
# Nuovo Cinema Paradiso 1988 8.429194184256293
# Memento 2000 8.425920588956595
# Apocalypse Now 1979 8.425186029498422
# Raiders of the Lost Ark 1981 8.41168452037763
# Django Unchained 2012 8.40272119729866
# WALL·E 2008 8.39263577771518
# The Lives of Others 2006 8.386239079501415
# Sunset Blvd 1950 8.382386944081128
# Paths of Glory 1957 8.370803048814498
# The Shining 1980 8.367887437239709
# The Great Dictator 1940 8.36611158030714
# Witness for the Prosecution 1957 8.356779827191644
# Avengers: Infinity War 2018 8.355819216381763
# Aliens 1986 8.344671197329808
# American Beauty 1999 8.337824941051108
# Dr Strangelove or: How I Learned to Stop Worrying and Love the Bomb 1
# Groundhog Day 1993 8.032423115972797
# Ratatouille 2007 8.032238319222314
# Before Sunset 2004 8.028534343218373
# The Exorcist 1973 8.028227180892282
# The Best Years of Our Lives 1946 8.026215019983411
# The Incredibles 2004 8.025633708917995
# To Be or Not to Be 1942 8.024803979060843
# The Grapes of Wrath 1940 8.022794505402981
# Rebecca 1940 8.022755781166374
# La battaglia di Algeri 1966 8.02264216448294
# Hachi: A Dog's Tale 2009 8.021610959110731
# Cool Hand Luke 1967 8.021326649071055
# Amores perros 2000 8.020985295292828
# Pirates of the Caribbean: The Curse of the Black Pearl 2003 8.018913567179045
# La haine 1995 8.016313610840983
# Les quatre cents coups 1959 8.016132624568247
# Persona 1966 8.01587878010827
# Life of Brian 1979 8.014630753188422
# Babam ve Oglum 2005 8.01459731228941
# Dersu Uzala 1975 8.014259600452256
# It Happened One Night 1934 8.013761917401194
# The Sound of Music 1965 8.013669929540542
# Ah-ga-ssi 2016 8.009214969898027
# Jai Bhim 2021 8.007421209986228
# Aladdin 1992 8.007004605151481
# Gandhi 1982 8.006461595855393
# The Help 2011 8.0046560747568
# Beauty and the Beast 1991 8.0031365347803

# %% [markdown]
# # President

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://presidentofindia.nic.in/former-presidents.htm'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

# %%
president = []

for i in soup.find_all("div", class_="presidentListing"):
    president.append(i.text)

president

# %% [markdown]
# # Mens team

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/mens/rankings-predictor/odi'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

odi_teams = []

for i in soup.find_all("div", class_="rankings-block__container full rankings-table"):
    odi_teams.append(i.text)

odi_teams

# %% [markdown]
# # Mens batsmen

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

batting = []

for i in soup.find_all("table", class_="table rankings-table"):
    batting.append(i.text)

batting

# %%
df =pd.DataFrame({'Pos':Pos, "Player":Player, 'Team':Team, "Rating":Rating})
df

# %% [markdown]
# # Mens Bolwers

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

bowlers = []

for i in soup.find_all("table", class_="table rankings-table"):
    bowlers.append(i.text)

bowlers

# %% [markdown]
# # Womens Team

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/womens/team-rankings/odi'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

odi_teams = []

for i in soup.find_all("div", class_="rankings-block__container full rankings-table"):
    odi_teams.append(i.text)

odi_teams

# %% [markdown]
# # Womens Batting

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

batting = []

for i in soup.find_all("table", class_="table rankings-table"):
    batting.append(i.text)

batting

# %% [markdown]
# # Womens Bowling

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi/bowling'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

bowlers = []

for i in soup.find_all("table", class_="table rankings-table"):
    bowlers.append(i.text)

bowlers

# %% [markdown]
# # cnbc

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

html = 'https://www.cnbc.com/world/?region=world'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

for headline in soup.findAll("h2"):
    print("Headline : {}".format(headline.text))
    
for link in h2:
    mylink = BeautifulSoup(str(link), 'html.parser')
    getttinglink= mylink.find('a',href=True)
    gettinglink

# %% [markdown]
# # Dineout

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.dineout.co.in/delhi-restaurants/buffet-special'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

Restaurant = []

for i in soup.find_all("div", class_="restnt-info cursor"):
    Restaurant.append(i.text)

Restaurant

# %%
Cuisine = []

for i in soup.find_all("span", class_="double-line-ellipsis"):
    Cuisine.append(i.text)

Cuisine

# %%
Ratings = []

for i in soup.find_all("div", class_="restnt-rating rating-4"):
    Ratings.append(i.text)

Ratings

# %%
image = []

for i in soup.find_all("img", class_="no-img"):
    image.append(i['data-src'])
                

image

# %% [markdown]
# # Google scholar

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://scholar.google.com/citations?view_op=top_venues&hl=en'
response = requests.get(url)

soup = BeautifulSoup(response.content)
soup

data = []

for i in soup.find_all("td", class_="gsc_mvt_p"):
    data.append(i.text)


data
